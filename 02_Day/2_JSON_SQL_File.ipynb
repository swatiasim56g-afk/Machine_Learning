# %% [markdown]
# # JSON File & SQL File

# %%
import pandas as pd

# %% [markdown]
# ## Working With JSON

# %%
pd.read_json('data.json')

# %% [markdown]
# ### JSON by URL

# %%
pd.read_json('url')

# %% [markdown]
# ## Working With SQL

# %%
# !pip install mysql-connector

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="mydatabase"
)

# %%
pd.read_mysql("SELECT * FROM mytable", conn)
