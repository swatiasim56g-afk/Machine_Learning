# %% [markdown]
# # Pandas Profilling Tool

# %%
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (3.6.6)
# Requirement already satisfied: ydata-profiling in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from pandas-profiling) (4.16.1)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (3.9.2)
# Requirement already satisfied: pydantic>=2 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (2.12.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (2.1.3)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.1)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=3 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (1.8.1)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from ydata-profiling->pandas-profiling) (0.61.0)
# Requirement already satisfied: pillow in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (11.1.0)
# Requirement already satisfied: PyWavelets in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from numba<=0.61,>=0.56.0->ydata-profiling->pandas-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling->pandas-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling->pandas-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.5.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2026.1.4)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling->pandas-profiling) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from typeguard<5,>=3->ydata-profiling->pandas-profiling) (4.15.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (3.4.2)
# Requirement already satisfied: puremagic in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (1.28)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\muhammad asim\miniconda3\envs\ml_python\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.17.0)

# %% [markdown]
# ## Upload Data Set

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# upload the of titanic dataset
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# import pandas pandas profiling 
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[25], line 2
#       1 # import pandas pandas profiling
# ----> 2 import pandas_profiling as pp
#
# File c:\Users\Muhammad Asim\miniconda3\envs\ml_python\lib\site-packages\pandas_profiling\__init__.py:8
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
#       6 from warnings import warn
# ----> 8 from pandas_profiling.compare_reports import compare
#       9 from pandas_profiling.controller import pandas_decorator
#      10 from pandas_profiling.profile_report import ProfileReport
#
# File c:\Users\Muhammad Asim\miniconda3\envs\ml_python\lib\site-packages\pandas_profiling\compare_reports.py:6
#       2 from typing import Any, List, Optional, Tuple, Union
#       4 import pandas as pd
# ----> 6 from pandas_profiling.config import Correlation, Settings
#       7 from pandas_profiling.model.alerts import Alert
#       8 from pandas_profiling.profile_report import ProfileReport
#
# File c:\Users\Muhammad Asim\miniconda3\envs\ml_python\lib\site-packages\pandas_profiling\config.py:7
#       4 from typing import Any, Dict, List, Optional, Tuple, Union
#       6 import yaml
# ----> 7 from pydantic import BaseModel, BaseSettings, Field, PrivateAttr
#      10 def _merge_dictionaries(dict1: dict, dict2: dict) -> dict:
#      11     """
#      12     Recursive merge dictionaries.
#      13
#    (...)
#      16     :return: Merged dictionary
#      17     """
#
# File c:\Users\Muhammad Asim\miniconda3\envs\ml_python\lib\site-packages\pydantic\__init__.py:437, in __getattr__(attr_name)
#     435 dynamic_attr = _dynamic_imports.get(attr_name)
#     436 if dynamic_attr is None:
# --> 437     return _getattr_migration(attr_name)
#     439 package, module_name = dynamic_attr
#     441 if module_name == '__module__':
#
# File c:\Users\Muhammad Asim\miniconda3\envs\ml_python\lib\site-packages\pydantic\_migration.py:304, in getattr_migration.<locals>.wrapper(name)
#     302     return import_string(REDIRECT_TO_V1[import_path])
#     303 if import_path == 'pydantic:BaseSettings':
# --> 304     raise PydanticImportError(
#     305         '`BaseSettings` has been moved to the `pydantic-settings` package. '
#     306         f'See https://docs.pydantic.dev/{version_short()}/migration/#basesettings-has-moved-to-pydantic-settings '
#     307         'for more details.'
#     308     )
#     309 if import_path in REMOVED_IN_V2:
#     310     raise PydanticImportError(f'`{import_path}` has been removed in V2.')
#
# PydanticImportError: `BaseSettings` has been moved to the `pydantic-settings` package. See https://docs.pydantic.dev/2.12/migration/#basesettings-has-moved-to-pydantic-settings for more details.
#
# For further information visit https://errors.pydantic.dev/2.12/u/import-error

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_file("pandas_profiling_report.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 profile = ProfileReport(df, title="Pandas Profiling Report")
#       2 profile.to_file("pandas_profiling_report.html")
#
# NameError: name 'ProfileReport' is not defined
